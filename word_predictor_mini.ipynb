# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
file_path = "/content/sherlock.txt"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([text])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'i': 6,
#  '”': 7,
#  'in': 8,
#  'that': 9,
#  'it': 10,
#  'he': 11,
#  'was': 12,
#  'you': 13,
#  'his': 14,
#  'is': 15,
#  'my': 16,
#  'have': 17,
#  'with': 18,
#  'as': 19,
#  'had': 20,
#  'at': 21,
#  'which': 22,
#  'for': 23,
#  'be': 24,
#  'not': 25,
#  'me': 26,
#  'but': 27,
#  'from': 28,
#  'we': 29,
#  'this': 30,
#  'said': 31,
#  'upon': 32,
#  'there': 33,
#  'holmes': 34,
#  'him': 35,
#  'so': 36,
#  'her': 37,
#  'she': 38,
#  'all': 39,
#  '’': 40,
#  'been': 41,
#  'your': 42,
#  'on': 43,
#  'very': 44,
#  'by': 45,
#  'one': 46,
#  'are': 47,
#  '“i': 48,
#  'were': 49,
#  'an': 50,
#  'no': 51,
#  'would': 52,
#  'out': 53,
#  'what': 54,
#  'then': 55,
#  'up': 56,
#  'when': 57,
#  'man': 58,
#  'could': 59,
#  'has': 60,
#  'do': 61,
#  'into': 62,
#  'or': 63,
#  'little': 64,
#  'will': 65,
#  'who': 66,
#  'mr': 67,
#  'if': 68,
#  'some': 69,
#  'down': 70,
#  'see': 71,
#  'now': 72,
# ...

# %%
input_sequences=[]

for sentence in text.split('\n'):
  # print(tokenizer.texts_to_sequences([sentence])[0])
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[145, 4789],
#  [145, 4789, 1],
#  [145, 4789, 1, 1020],
#  [145, 4789, 1, 1020, 4],
#  [145, 4789, 1, 1020, 4, 128],
#  [145, 4789, 1, 1020, 4, 128, 34],
#  [145, 4789, 1, 1020, 4, 128, 34, 45],
#  [145, 4789, 1, 1020, 4, 128, 34, 45, 611],
#  [145, 4789, 1, 1020, 4, 128, 34, 45, 611, 2235],
#  [145, 4789, 1, 1020, 4, 128, 34, 45, 611, 2235, 2236],
#  [30, 1021],
#  [30, 1021, 15],
#  [30, 1021, 15, 23],
#  [30, 1021, 15, 23, 1],
#  [30, 1021, 15, 23, 1, 275],
#  [30, 1021, 15, 23, 1, 275, 4],
#  [30, 1021, 15, 23, 1, 275, 4, 394],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237, 21],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237, 21, 51],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237, 21, 51, 1676],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237, 21, 51, 1676, 2],
#  [30, 1021, 15, 23, 1, 275, 4, 394, 2237, 21, 51, 1676, 2, 18],
#  [572, 51],
#  [572, 51, 3398],
#  [572, 51, 3398, 3399],
#  [572, 51, 3398, 3399, 13],
#  [572, 51, 3398, 3399, 13, 75],
# ...

# %%
lengths=[]
for x in input_sequences:
  lengths.append(len(x))

max_len = max(lengths)

# %%
print(max_len)
# Out:
# 20

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_input_sequences=pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[   0,    0,    0, ...,    0,  145, 4789],
#        [   0,    0,    0, ...,  145, 4789,    1],
#        [   0,    0,    0, ..., 4789,    1, 1020],
#        ...,
#        [   0,    0,    0, ...,    3,  360,   83],
#        [   0,    0,    0, ...,  360,   83,  358],
#        [   0,    0,    0, ...,   83,  358, 1673]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]
y =padded_input_sequences[:,-1]

# %%
# we cannot make this a regression task as there will be no output for decimal values
# so we will consider this as a multiclass classification task and out outputs will be one hot encoded

# %%
X.shape
# Out:
# (101619, 19)

# %%
y.shape
# Out:
# (101619,)

# %%
total_words = len(tokenizer.word_index)

print(total_words)
# Out:
# 8930

# %%
from tensorflow.keras.utils import to_categorical

y=to_categorical(y, num_classes=8931)

# %%
y.shape
# Out:
# (101619, 8931)

# %%
# embedding | LSTM | dense

from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.models import Model

maxlen = 19  # Example input length
max_features = 8931  # Size of the vocabulary
embed_size = 100  # Embedding dimension size

# Input layer
inp = Input(shape=(maxlen, ))

# Embedding layer
x = Embedding(input_dim=max_features, output_dim=embed_size)(inp)

# LSTM layer
x = LSTM(150)(x)

# Add a fully connected layer
x = Dense(8931, activation="softmax")(x)

# Define the model
model = Model(inputs=inp, outputs=x)

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 19)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_4 (Embedding)         │ (None, 19, 100)        │       893,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8931)           │     1,348,581 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,392,281 (9.13 MB)
#  Trainable params: 2,392,281 (9.13 MB)
# ...

# %%
model.fit(X,y,epochs=50)
# Out:
# Epoch 1/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 30s 9ms/step - accuracy: 0.0619 - loss: 6.5936
# Epoch 2/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 9ms/step - accuracy: 0.1221 - loss: 5.5370
# Epoch 3/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 9ms/step - accuracy: 0.1554 - loss: 5.0703
# Epoch 4/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 9ms/step - accuracy: 0.1729 - loss: 4.7065
# Epoch 5/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 28s 9ms/step - accuracy: 0.1959 - loss: 4.3526
# Epoch 6/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 8ms/step - accuracy: 0.2189 - loss: 4.0559
# Epoch 7/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 8ms/step - accuracy: 0.2513 - loss: 3.7462
# Epoch 8/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 9ms/step - accuracy: 0.2884 - loss: 3.4739
# Epoch 9/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 27s 9ms/step - accuracy: 0.3253 - loss: 3.2171
# Epoch 10/50
# 3176/3176 ━━━━━━━━━━━━━━━━━━━━ 28s 9ms/step - accuracy: 0.3685 - loss: 2.9718
# Epoch 11/50
# ...

# %%
import numpy as np

# %%
test = "necessarily"

for i in range(5):
  token_text=tokenizer.texts_to_sequences([test])[0]
  padded_token_text=pad_sequences([token_text], maxlen=19, padding='pre')
  position=np.argmax(model.predict(padded_token_text))

  for word, index in tokenizer.word_index.items():
    if index==position:
      test = test+" "+word
      print(test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# necessarily keep
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# necessarily keep ebooks
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# necessarily keep ebooks in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# necessarily keep ebooks in compliance
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# necessarily keep ebooks in compliance with
